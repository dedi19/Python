# %%
import requests
r = requests.get("https://www.thejakartapost.com")
r.status_code
r.headers
# Out:
# {'Date': 'Wed, 29 Apr 2020 19:39:08 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d3a78cc1e967270df35a0e15ce89059101588189148; expires=Fri, 29-May-20 19:39:08 GMT; path=/; domain=.thejakartapost.com; HttpOnly; SameSite=Lax; Secure, XSRF-TOKEN=%3D%3D; expires=Thu, 30-Apr-2020 19:39:08 GMT; Max-Age=86400; path=/; domain=www.thejakartapost.com; secure, laravel_session=
# ...
